# %%
from typing import  Tuple

CloneId = Tuple[int, ...]

class ChildLabelBuilder:
    def generate(self, parent_id: CloneId, child_number: int) -> CloneId:
        return parent_id + (child_number,)

# %%
labeler = ChildLabelBuilder()
print(labeler.generate((1,2), 3))
# Out:
# (1, 2, 3)
