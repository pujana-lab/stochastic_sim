# %%
import src.gillespie as simulator
from src.gillespie.tumor_simulation import TumorSimulation
from src.gillespie.simulation_config import SimulationConfig
from src.gillespie.clone_type import CloneType

# %%
A= TumorSimulation(config=SimulationConfig)
tissue = A.tissue_state
for clones in tissue.clones.values():
    print(clones.cell_type.value)

    print(tissue.get_clones_by_type(clones.cell_type))
    print(tissue.population_by_type(clones.cell_type))
# Out:
# base
# {(): WildTypeClone(), (1,): WildTypeClone()}
# 1010
# base
# {(): WildTypeClone(), (1,): WildTypeClone()}
# 1010
# mutated
# {(0,): MutatedClone()}
# 1
# immune
# {(-1,): ImmuneClone()}
# 10
# exhausted
# {(-2,): ExhaustedClone()}
# 0

# %%
print(A.tissue_state.snapshot())
clones=A.tissue_state.clones

print(A.tissue_state.population_by_type(CloneType("base")))
print(A.tissue_state.population_by_type(CloneType("mutated")))
print(tissue.clones)
# Out:
# {(): {'N': 10, 'rb': 0.5, 'rd': 0.2, 'rm': 0.0, 're': 0.0}, (1,): {'N': 997, 'rb': 0.5, 'rd': 0.2, 'rm': 0.0, 're': 0.0}, (0,): {'N': 1, 'rb': 0.525, 'rd': 0.2, 'rm': 0.0, 're': 0.0}, (-1,): {'N': 10, 'rb': 0.5, 'rd': 0.0, 'rm': 0.0, 're': 0.3}, (-2,): {'N': 0, 'rb': 0.0, 'rd': 0.2, 'rm': 0.0, 're': 0.0}, (1, 1): {'N': 1, 'rb': 0.525, 'rd': 0.2, 'rm': 0.0, 're': 0.0}, (1, 2): {'N': 1, 'rb': 0.525, 'rd': 0.2, 'rm': 0.0, 're': 0.0}, (1, 3): {'N': 1, 'rb': 0.525, 'rd': 0.2, 'rm': 0.0, 're': 0.0}}
# 1006
# 5
# {(): WildTypeClone(), (1,): WildTypeClone(), (0,): MutatedClone(), (-1,): ImmuneClone(), (-2,): ExhaustedClone(), (1, 1): MutatedClone(), (1, 2): MutatedClone(), (1, 3): MutatedClone(), (1, 4): MutatedClone()}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 for type in CloneType():
#       2     print (type)
#
# TypeError: EnumType.__call__() missing 1 required positional argument: 'value'
