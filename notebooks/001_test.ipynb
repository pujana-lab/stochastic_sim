# %% [markdown]
# Notebook 1 de ejemplo. Vamos a crear un objeto básico que tenga poblaciones y que permita trabajar sobre ellas. En esta primera fase vamos a crear una base que cuente todos los elementos que hay

# %%
from population import Population, SubPopulation
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[10], line 1
#
# ----> 1 from src.population import Population, SubPopulation
#
#
#
# ModuleNotFoundError: No module named 'src'

# %%
# Creamos una población vacía mínima
dictionary = {
    "pop" : 100 
}

dictionary
# Out:
# {'pop': 100}

# %%
# Contamos el número de individuos en la población

dictionary['pop']
# Out:
# 100
