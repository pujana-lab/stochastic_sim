# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../history.csv")
print(df.head())
# Out:
#        time      clone_id    N     rb     rd
# 0  0.000000          root  200  0.005  0.002
# 1  0.000000  mutated_root   10  0.006  0.002
# 2  0.000000        immune   50  0.005  0.000
# 3  0.000000     exhausted    0  0.000  0.002
# 4  0.464779          root  200  0.005  0.002
